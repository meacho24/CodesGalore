# %% [markdown]
# <a href="https://colab.research.google.com/github/meacho24/CodesGalore/blob/main/Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo.gif](data:image/gif;base64,...)

# %% [markdown]
# # **LACC STEM Core Summer Bridge Program**
# ---
#
#
# ## Graphical Summaries for Qualitative Data
#
# Statistics is a process.  The first chapter (Part I) dealt with the first two steps in the statistical process: (1) identify the research objective and (2) collect the information needed to answer the questions in the research objective.  The next two chapters in the text deal with organizing, summarizing, and presenting the data collected.  The step in the process is called descriptive statistics.
# ---

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b>Definition:</b> A frequency distribution lists each category of the data and the number of occurrences for each category of data.
#
# <b>Definition:</b> The relative frequency is the proportion or percent of observations within a category and is found using the formula.
#
# > **Relative Frequency =** $\frac{\text{frequency of category}}{\sum_{i=1}^n \text{frequencies}}$
#
# <b>Definition:</b> A relative frequency distribution lists each category of data together with the relative frequency.
# </div>

# %%
# Library
import random

# List of names
names = ["Bob", "Scarlett", "Mary", "Eli", "Terry", "Bill", "Fisher", "Megan", "Evan", "West", "Brandon", "George", "Murphy", "Kayla", "Williams", "Bryant", "Grant", "Lee", "Max", "Molly", "Conor", "Kapono", "Wilson", "Mia", "Salma"]

# Choose 5 names without replacement
random_names = random.sample(names, 5)

print("Randomly chosen names:", random_names)
# Out:
# Randomly chosen names: ['Max', 'Brandon', 'Evan', 'Grant', 'Murphy']

# %% [markdown]
# **Example 1:** The preschool children at Elmwood Elementary School were asked to name their favorite color.  The results are listed below:
#
#             Yellow           Yellow          Red              Purple            Blue
#
#             Blue              Blue           Yellow           Blue              Red
#
#             Blue              Red            Purple           Purple            Purple
#
#             Red               Blue           Purple           Blue              Green
#
# Using the data given, construct the following.

# %%
# Library
import random

# Set the random seed for reproducibility
random.seed(47)  # You can replace 42 with any integer value you prefer

# List of names
names = ["Bob", "Scarlett", "Mary", "Eli", "Terry", "Bill", "Fisher", "Megan", "Evan", "West", "Brandon", "George", "Murphy", "Kayla", "Williams", "Bryant", "Grant", "Lee", "Max", "Molly", "Conor", "Kapono", "Wilson", "Mia", "Salma"]

# Choose 5 names without replacement
random_names = random.sample(names, 5)

print("Randomly chosen names:", random_names)
# Out:
# Randomly chosen names: ['George', 'Mary', 'Kayla', 'Lee', 'Williams']

# %% [markdown]
# **Example 1:** part (a) Construct a freqency distribution and relative freqency distribion in Python.

# %%
# Library
import pandas as pd

# Create DataFrame
df = pd.DataFrame({'Freq': [3, 7, 4 ,5, 1]})
df.index = ['Yellow', 'Blue', 'Red', 'Purple', 'Green']

# Sort DataFrame by count descending
df = df.sort_values(by='Freq', ascending=False)

# Add column to display the relative Frequency
df['Rel.Freq'] = df['Freq']/df['Freq'].sum()*100


#view DataFrame
print(df)
# Out:
#         Freq  Rel.Freq
# Blue       7      35.0
# Purple     5      25.0
# Red        4      20.0
# Yellow     3      15.0
# Green      1       5.0

# %% [markdown]
# **Construct Bar Graphs**
#
#
# <div class="alert alert-block alert-info">
# <b>Definition:</b> A bar graph is constructed by labeling each category of data on the horizontal axis and the frequency or relative frequency of the category on the vertical axis.  Rectangles (bars) of equal width are drawn for each category and the bars do not touch.  The height of the rectangle is equal to the category’s frequency or relative frequency.
#
# </div>

# %% [markdown]
# **Example 1:** part (b) Construct a freqency barplot

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt

# create a dataset
Freq = [3,7,4,5,1]
bars = ('Yellow', 'Blue', 'Red', 'Purple', 'Green')
x_pos = np.arange(len(bars))

# Create bars with different colors
plt.bar(x_pos, Freq, color=['Yellow','Blue','Red','Purple','Green'])

# Create names on the x-axis
plt.xticks(x_pos,bars)

# Name
plt.ylabel('Freq')
plt.xlabel('Colors')
plt.title('Children Favorite Colors')

# Show graph
plt.show()

# %%
import plotly.express as px

# Create a dataset
Freq = [3,7,4,5,1]
colors = ['yellow', 'blue', 'red', 'purple', 'green']

# Create a bar graph
fig = px.bar(x=colors, y=Freq, color=colors)

# Set the title
fig.update_layout(title='Children Favorite Colors')

# Show the graph
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Example 1:** part (b) Construct a relative freqency barplot

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt

# create a dataset
RelFreq = [15,35,20,25,5]
bars = ('Yellow', 'Blue', 'Red', 'Purple', 'Green')
x_pos = np.arange(len(bars))

# Create bars with different colors
plt.bar(x_pos, RelFreq, color=['Yellow','Blue','Red','Purple','Green'])

# Create names on the x-axis
plt.xticks(x_pos,bars)

# Name
plt.ylabel('Rel. Freq.')
plt.xlabel('Colors')
plt.title('Children Favorite Color')

# Show graph
plt.show()

# %%
import plotly.express as px

# Create a dataset
colors = ['Yellow', 'Blue', 'Red', 'Purple', 'Green']
values = [15,35,20,25,5]

# Create a bar graph
fig = px.bar(y=values, color=colors, orientation='v')

# Set the title
fig.update_layout(title='Children Favorite Color', yaxis_title='Relative Frequency')

# Show the graph
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Example 1:** Pareto Chart

# %%
# Libraries
import matplotlib.pyplot as plt
from matplotlib.ticker import PercentFormatter
import pandas as pd

# Sample data
data = {
    'Colors': ['Blue', 'Purple', 'Red', 'Yellow', 'Green'],
    'Rel.Freq': [0.2, 0.15, 0.25, 0.1, 0.3]  # These values are just placeholders, replace with actual data
}

# Create DataFrame
df = pd.DataFrame(data)
df = df.sort_values(by='Rel.Freq', ascending=False)  # Sort by relative frequency

# Calculate cumulative percentage
df['Cumulative %'] = df['Rel.Freq'].cumsum() * 100

# Define aesthetics for plot
color1 = 'Blue'
color2 = ['Blue', 'Purple', 'Red', 'Yellow', 'Green']

# Create Pareto chart
fig, ax1 = plt.subplots()

# Bar plot on the primary axis
ax1.bar(df['Colors'], df['Rel.Freq'], color=color2)
ax1.set_xlabel('Colors')
ax1.set_ylabel('Relative Frequency', color=color1)
ax1.tick_params(axis='y', colors=color1)


# Title
plt.title('Pareto Chart - Children Favorite Color')

# Display Pareto chart
plt.show()

# %% [markdown]
# **Analysis as a Data Science you have two options in how to interpret:**
# 60 out 100 of the children favorite color is blue and purple
# From the helping perspective:
# Teachers should have this colors in their classrooms.
# From the business perspective:
# The crayon company should make boxes with only this two colors and put them at the higher prices.

# %% [markdown]
# **Construct pie charts**
#
# <div class="alert alert-block alert-info">
# <b>Definition:</b>  A pie chart is a circle divided into sectors.  Each sector represents a category of data.  The area of each sector is proportional to the frequency of the category.
#
# </div>

# %% [markdown]
# **Example 1 (d):** Construct a pie chart

# %%
# libraries
import numpy as np
import matplotlib.pyplot as plt

# Pie with specific wedgeprops option:
plt.pie(RelFreq, labels=bars, labeldistance=1.15, wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' });

# Create a set of colors
colors = ['Yellow','Blue','Red','Purple','Green']
# Use it thanks to the color argument
plt.pie(RelFreq, labels=bars, labeldistance=1.15, wedgeprops = { 'linewidth' : 7, 'edgecolor' : 'white' },
        colors=colors, autopct='%1.1f%%');

# %%
import plotly.express as px

# Create a dataset
RelFreq = [15,35,20,25,5]
bars = ['Yellow','Blue','Red','Purple','Green']
colors = ['yellow', 'red', 'blue', 'purple', 'green']

# Create a pie chart
fig = px.pie(values=RelFreq, names=bars, color=colors,
            width=400, height=400)

# Show the graph
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Example 2:**  A criminologist wanted to know if there was any relation between age and gender of murder victims.  The following data represent the number of male and female murder victims by age in 2006.
#
# | Age           | Number of Males | Number of Females |
# |---------------|-----------------|-------------------|
# | Less than 17  | 791             | 373               |
# | 17-24         | 3,762           | 550               |
# | 25-34         | 3,220           | 599               |

# %% [markdown]
# (a)  Construct a relative frequency distribution for males and a relative frequency distribution for females.

# %%
# Data
age_groups = ["Less than 17", "17-24", "25-34"]
males = [791, 3762, 3220]
females = [373, 550, 599]

# Calculate total males and females
total_males = sum(males)
total_females = sum(females)

# Calculate relative frequencies
relative_freq_males = [male / total_males for male in males]
relative_freq_females = [female / total_females for female in females]

# Print the results
print("Age Group      Rel. Freq (Males)  Rel. Freq (Females)")
for i in range(len(age_groups)):
    print(f"{age_groups[i]:<15} {relative_freq_males[i]:<18.4f} {relative_freq_females[i]:<18.4f}")
# Out:
# Age Group      Rel. Freq (Males)  Rel. Freq (Females)
# Less than 17    0.1018             0.2451
# 17-24           0.4840             0.3614
# 25-34           0.4143             0.3936

# %% [markdown]
# Construct a side-by-side relative frequency bar graph.

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
age_groups = ["Less than 17", "17-24", "25-34"]
males = [791, 3762, 3220]
females = [373, 550, 599]

# Calculate total males and females
total_males = sum(males)
total_females = sum(females)

# Calculate relative frequencies
relative_freq_males = [male / total_males for male in males]
relative_freq_females = [female / total_females for female in females]

# Bar width and positions
bar_width = 0.35
x = np.arange(len(age_groups))

# Create the bar graph
plt.bar(x - bar_width/2, relative_freq_males, width=bar_width, label='Males', color='blue')
plt.bar(x + bar_width/2, relative_freq_females, width=bar_width, label='Females', color='pink')

# Adding labels and title
plt.xlabel('Age Group')
plt.ylabel('Relative Frequency')
plt.title('Relative Frequency of Murder Victims by Age and Gender')
plt.xticks(x, age_groups)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
#
# #### **Now it's your turn! Try Problem on your own.**
#
# ---

# %% [markdown]
# **Practice:**  A survey of US adults aged 18 and older in 2003 and 2007 were asked, “Which of the following describes how spam affects your life on the Internet?”
#
# | Feeling             | 2003 | 2007 |
# |---------------------|------|------|
# | Big Problem         | 373  | 269  |
# | Annoying            | 850  | 761  |
# | No problem at all   | 239  | 418  |

# %% [markdown]
# (a)  Construct a relative frequency distribution for 2003 and a relative frequency distribution for 2007.

# %%
# Data
spam = ["Big", "Ann", "Noprob"]
year_2003 = [373, 850, 239]
year_2007 = [269, 761, 418]

# Calculate total males and females
total_year_2003 = sum(year_2003)
total_year_2007 = sum(year_2007)

# Calculate relative frequencies
total_year_2003_freq = [year_2003 / total_year_2003 for year_2003 in year_2003]
total_year_2007_freq = [year_2007 / total_year_2007 for year_2007  in year_2007 ]

# Print the results
print("Feeling      Rel. Freq (2003)  Rel. Freq (2007)")
for i in range(len(spam)):
    print(f"{spam[i]:<15} {total_year_2003_freq[i]:<18.4f} {total_year_2007_freq[i]:<18.4f}")
# Out:
# Feeling      Rel. Freq (2003)  Rel. Freq (2007)
# Big             0.2551             0.1858
# Ann             0.5814             0.5256
# Noprob          0.1635             0.2887

# %% [markdown]
# (b)  Construct a side-by-side relative frequency bar graph.

# %%
import matplotlib.pyplot as plt
import numpy as np

spam = ["Big", "Ann", "Noprob"]
year_2003 = [373, 850, 239]
year_2007 = [269, 761, 418]

# Calculate total males and females
total_males = sum(males)
total_females = sum(females)

# Calculate relative frequencies
relative_freq_males = [male / total_males for male in males]
relative_freq_females = [female / total_females for female in females]

# Bar width and positions
bar_width = 0.35
x = np.arange(len(age_groups))

# Create the bar graph
plt.bar(x - bar_width/2, relative_freq_males, width=bar_width, label='Males', color='blue')
plt.bar(x + bar_width/2, relative_freq_females, width=bar_width, label='Females', color='pink')

# Adding labels and title
plt.xlabel('Age Group')
plt.ylabel('Relative Frequency')
plt.title('Relative Frequency of Murder Victims by Age and Gender')
plt.xticks(x, age_groups)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Construct Histograms**
#
# <div class="alert alert-block alert-info">
# <b>Definition:</b>   A histogram is constructed by drawing rectangles for each class of data.  The height of each rectangle is the frequency or relative frequency of the class.  The width of each rectangle is the same and the rectangles touch each other.
#
# </div>

# %% [markdown]
# **Example 1:**  A researcher wanted to determine the number of televisions in households.  He conducts a survey of randomly selected households and obtains the following data.
#
# | 1 | 1 | 4 | 2 | 3 | 3 | 5 | 1 | 2 | 3 | 2 | 2 | 1 | 2 | 3 | 2 | 1 | 2 | 2 | 2 | 2 | 1 | 3 | 1 |
# |---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|
#
#
#
#
# (a)  Construct a frequency distribution and a relative frequency distribution of the data.

# %%
import numpy as np

# Provided data
data = [
    1, 1, 4, 2, 3, 3, 5, 1,
    2, 3, 2, 2, 1, 2, 3, 2,
    1, 2, 2, 2, 2, 1, 3, 1
]

# Calculate frequency distribution
frequency_dist = {}
for value in data:
    if value in frequency_dist:
        frequency_dist[value] += 1
    else:
        frequency_dist[value] = 1

# Calculate relative frequency distribution
total_values = len(data)
relative_frequency_dist = {value: count / total_values for value, count in frequency_dist.items()}

# Print frequency distribution
print("Frequency Distribution:")
for value, count in frequency_dist.items():
    print(f"{value}: {count}")

# Print relative frequency distribution
print("\nRelative Frequency Distribution:")
for value, rel_freq in relative_frequency_dist.items():
    print(f"{value}: {rel_freq:.2f}")
# Out:
# Frequency Distribution:
# 1: 7
# 4: 1
# 2: 10
# 3: 5
# 5: 1
#
# Relative Frequency Distribution:
# 1: 0.29
# 4: 0.04
# 2: 0.42
# 3: 0.21
# 5: 0.04

# %% [markdown]
# (b) Construct Histograms

# %%
import matplotlib.pyplot as plt

# Provided data
data = [
    1, 1, 4, 2, 3, 3, 5, 1,
    2, 3, 2, 2, 1, 2, 3, 2,
    1, 2, 2, 2, 2, 1, 3, 1
]

# Create a histogram
plt.hist(data, bins=range(1, 7), edgecolor='black', align='left', alpha=0.7)

# Add labels and title
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Data')

# Display the histogram
plt.show()

# %% [markdown]
# **Example 2:** The following data represent the time between eruptions (in seconds) for a random sample of eruptions at the Old Faithful Geyser in California.  Construct a frequency histogram.
#
# 728      730      726      698      721      722      700      720      729
#
# 678      722      716      702      703      718      703      723      699
#
# 703      713      672      711      695      731      726      695      718

# %%
# Library
import matplotlib.pyplot as plt

# Data represent the time between eruptions (in seconds) for a random sample of eruptions
data=[728,730,726,698,721,722,700,720,729,678,722,716,702,703,718,703,723,699,703,713,672,711,695,731,726,695,718]

# Display the histogram
plt.hist(data, bins=10, color = 'red', alpha=.3)
plt.xlabel('Eruptions between Seconds')
plt.ylabel('freq')
plt.title('Histogram Between Eruptions')
plt.show()

# %% [markdown]
# **Analysis as a Data Science you have two options in how to interpret:**
# Most of the eruptions will happen to be between 700 to 730 seconds.

# %% [markdown]
# <img src="https://media.giphy.com/media/26ufnwz3wDUli7GU0/giphy.gif">

# %% [markdown]
# ![Business+Card.jpg.gif](data:image/gif;base64,...)

# %% [markdown]
# ![CopyRight.gif](data:image/gif;base64,...)
